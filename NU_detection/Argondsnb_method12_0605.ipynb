# %%
import numpy as np
import os

import random
import pandas as pd
import math
import matplotlib.pyplot as plt
import itertools
import astropy.units as u
import astropy.constants as const
import scipy.stats as stats
from matplotlib.patches import Patch
from ast import literal_eval
from matplotlib.lines import Line2D

# %%
import sys

from s1s2_0311 import *
from read import *
from recoil_1223 import *
from plot_binned_detection_1d2d_0526 import *

# %%
folder_1d = 'unbinned_Er_pdf_itp'
nuclei_1d = 'Argon'
footnote = 'thrd'
E_threshold_keV = 1

# %%
pcles_NR = ['hep', '8B','dsnb',
                 'atmNu_CJPL_avg','atmNu_Kamioka_avg','atmNu_LNGS_avg', 'atmNu_SURF_avg', 'atmNu_SNOlab_avg' ]#

# %%
E_end = 350
bin_number = 40

# %%
binned_1d_pd = pd.DataFrame()

# %%
sigma_percentage = 0.1
# smear+eff argon 1d
binned_1d_pd = get_1d_pd_NR(binned_1d_pd, pcles_NR, nuclei_1d, ['high', 'low'], 
                                      binnum = bin_number, eff_types = ['NR_Argon_tot'], E_end = E_end, 
                                  corr ='_smear'+str(sigma_percentage), corr_sim = '_smear'+str(sigma_percentage), 
              folder_1d = '../unbinned_Er_pdf_itp', size = 10000000, 
                 E_threshold_keV = E_threshold_keV, unit_pdf = (u.tonne*u.yr*u.keV)**(-1), unit_Er = u.keV, print_check = True)
# Out:
# E_end =  350
# NR
# NR
# else
# _smear0.1 ../real_data_nest/pdf/hep_NR_Argon_pdf_high_smear0.1.txt
# NR_Argon_tot
# survival
# smear energy
# solar components
# ../unbinned_Er_pdf_itp/Er_hep_NR_Argon_NR_Argon_tot_10000000_thrd1keV_high_smear0.1.txt _smear0.1
# hep NR _ terminate at  29.069171944
# whole spectrum eventR =  0.01278286258758031 1 / (t yr)
# fraction of counts within Er  1.0 keV  to  350.0 keV =  1.0
# eventR within Er  1.0 keV  to  350.0 keV =  0.012782862587580313 1 / (t yr)
#
#
# NR
# NR
# else
# _smear0.1 ../real_data_nest/pdf/8B_NR_Argon_pdf_high_smear0.1.txt
# NR_Argon_tot
# survival
# smear energy
# solar components
# ../unbinned_Er_pdf_itp/Er_8B_NR_Argon_NR_Argon_tot_10000000_thrd1keV_high_smear0.1.txt _smear0.1
# 8B NR _ terminate at  29.069171944
# whole spectrum eventR =  0.08961692264968567 1 / (t yr)
# fraction of counts within Er  1.0 keV  to  350.0 keV =  1.0
# eventR within Er  1.0 keV  to  350.0 keV =  0.08961692264968567 1 / (t yr)
#
#
# NR
# NR
# ...

# %%
binned_1d_pd = get_1d_pd_NR(binned_1d_pd, pcles_NR, nuclei_1d, ['high', 'low'], 
                                      binnum = bin_number, eff_types = [''], E_end = E_end, 
                            corr ='', corr_sim = '', 
              folder_1d = '../unbinned_Er_pdf_itp', size = 10000000, 
                 E_threshold_keV = E_threshold_keV, unit_pdf = (u.tonne*u.yr*u.keV)**(-1), unit_Er = u.keV, print_check = True)
# Out:
# E_end =  350
# NR
# NR
# else
#  ../real_data_nest/pdf/hep_NR_Argon_pdf_high.txt
# survival
# other
# ../unbinned_Er_pdf_itp/Er_hep_NR_Argon__10000000_thrd1keV.txt
# hep NR _ terminate at  18.564849132
# whole spectrum eventR =  0.5073099081700151 1 / (t yr)
# fraction of counts within Er  1.0 keV  to  350.0 keV =  1.0
# eventR within Er  1.0 keV  to  350.0 keV =  0.507309908170015 1 / (t yr)
#
#
# NR
# NR
# else
#  ../real_data_nest/pdf/8B_NR_Argon_pdf_high.txt
# survival
# other
# ../unbinned_Er_pdf_itp/Er_8B_NR_Argon__10000000_thrd1keV.txt
# 8B NR _ terminate at  13.978393016
# whole spectrum eventR =  128.14863738526384 1 / (t yr)
# fraction of counts within Er  1.0 keV  to  350.0 keV =  1.0
# eventR within Er  1.0 keV  to  350.0 keV =  128.14863738526387 1 / (t yr)
#
#
# NR
# NR
#  ../real_data_nest/pdf/dsnb_Ar.txt
# survival
# other
# ../unbinned_Er_pdf_itp/Er_dsnb_NR_Argon__10000000_thrd1keV.txt
# dsnb NR _ terminate at  365.066
# ...

# %%
effs_corrs = [('', ''), ('NR_Argon_tot', '_smear'+str(sigma_percentage))]
for eff_corr in effs_corrs:
    eff, corr = eff_corr 
    print(''.join(eff_corr), len([col for col in binned_1d_pd.columns if '_'+eff+'_' in col and corr in col]))
# Out:
#  16
# NR_Argon_tot_smear0.1 16

# %%
detectors = ['CJPL', 'Kamioka', 'LNGS', 'SURF', 'SNOlab']
metallicities = ['high', 'low']
alphas_powers = [(0.001, 0.9), (0.01, 0.9),  (0.1, 0.9),
                (0.001, 0.95), (0.01, 0.95), (0.1, 0.95),
                (0.001, 0.8), (0.01, 0.8), (0.1, 0.8)]

# %%
result_pd = pd.DataFrame(index = [str(alpha_power) for alpha_power in alphas_powers],
                         columns=[detector+'_'+metallicity+'_'+(''.join(eff_corr))+'_'+method for detector in detectors 
                                  for  metallicity in metallicities
                                  for eff_corr in effs_corrs 
                                 for method in ['allDSNBMethod1', 'allDSNBMethod2', 
                                                'noelsebgMethod1', 'noelsebgMethod2',
                                                'lessatmbgMethod1', 'lessatmbgMethod2',
                                                'lessatmlesselseMethod1', 'lessatmlesselseMethod2']])

# %%
result_pd
# Out:
#               CJPL_high__allDSNBMethod1 CJPL_high__allDSNBMethod2  \
# (0.001, 0.9)                        NaN                       NaN
# (0.01, 0.9)                         NaN                       NaN
# (0.1, 0.9)                          NaN                       NaN
# (0.001, 0.95)                       NaN                       NaN
# (0.01, 0.95)                        NaN                       NaN
# (0.1, 0.95)                         NaN                       NaN
# (0.001, 0.8)                        NaN                       NaN
# (0.01, 0.8)                         NaN                       NaN
# (0.1, 0.8)                          NaN                       NaN
#
#               CJPL_high__noelsebgMethod1 CJPL_high__noelsebgMethod2  \
# (0.001, 0.9)                         NaN                        NaN
# (0.01, 0.9)                          NaN                        NaN
# (0.1, 0.9)                           NaN                        NaN
# ...

# %%
exposures = [int(i) for i in np.logspace(np.log10(1e4), np.log10(1e6), 26)]
Er_bincenters = list(binned_1d_pd['Argon_Er_bincenters [keV]'])
for eff_corr in effs_corrs:
    eff, corr = eff_corr 
    print(eff_corr)
    for detector in detectors:
        print(detector)
        for metallicity in metallicities:
            pcles_det = ['dsnb']
            select_col_det  = [col for col in binned_1d_pd.columns 
                               if '_'+eff+'_' in col and corr in col and 
                               metallicity in col and any(pcle in col for pcle in pcles_det)]

            pcles_null_NR_woatm =['hep', '8B']
            pcles_null_NR = ['hep', '8B','atmNu_'+detector+'_avg']
            pcles_null_atm_NR = ['atmNu_'+detector+'_avg']
            select_col_null_woatm  = [col for col in binned_1d_pd.columns 
                                      if '_'+eff+'_' in col and corr in col and 
                                      metallicity in col and any(pcle in col for pcle in pcles_null_NR_woatm)]
            select_col_null_atm  = [col for col in binned_1d_pd.columns 
                                    if '_'+eff+'_' in col and corr in col and 
                                    metallicity in col and any(pcle in col for pcle in pcles_null_atm_NR)]

            select_col_null  = [col for col in binned_1d_pd.columns 
                                if '_'+eff+'_' in col and corr in col and 
                                metallicity in col and any(pcle in col for pcle in pcles_null_NR)]

            if len(
                select_col_det) !=len(pcles_det) or len(
                select_col_null) !=len(pcles_null_NR) or len(
                select_col_null_woatm) !=len(pcles_null_NR_woatm) or len(
                select_col_null_atm) !=len(pcles_null_atm_NR):
                print('wrong selection',
                     select_col_det, pcles_det,'\n',
                     select_col_null, pcles_null_NR, '\n',
                     select_col_null_woatm, pcles_null_NR_woatm, '\n',
                     select_col_null_atm, pcles_null_atm_NR)
                break
            else:

                rates_det = list(np.sum(binned_1d_pd[select_col_det], axis = 1))/u.tonne/u.yr
                rates_null = list(np.sum(binned_1d_pd[select_col_null], axis = 1))/u.tonne/u.yr
                rates_null_woatm = list(np.sum(binned_1d_pd[select_col_null_woatm], axis = 1))/u.tonne/u.yr
                rates_null_atm = list(np.sum(binned_1d_pd[select_col_null_atm], axis = 1))/u.tonne/u.yr


                #keep all dsnb
                good1 = rates_det>0

                #remove all bgs except atm and dsnb exists
                good2 = np.multiply(rates_det>0, rates_null_woatm==0)

                #keep dsnb greater than atm
                good3 = rates_null_atm<rates_det 

                #keep dsnb greater than else bgs and greater than fraction of atm
                good4 = np.multiply(rates_null_atm<4*rates_det, rates_null_woatm<rates_det)


                start_index1, end_index1 = min(np.where(good1)[0]), max(np.where(good1)[0])
                start_index2, end_index2 = min(np.where(good2)[0]), max(np.where(good2)[0])
                start_index3, end_index3 = min(np.where(good3)[0]), max(np.where(good3)[0])
                start_index4, end_index4 = min(np.where(good4)[0]), max(np.where(good4)[0])

                rates_null_good1 = rates_null[start_index1:end_index1+1]
                rates_null_good2 = rates_null[start_index2:end_index2+1]
                rates_null_good3 = rates_null[start_index3:end_index3+1]
                rates_null_good4 = rates_null[start_index4:end_index4+1]

                rates_det_good1 = rates_det[start_index1:end_index1+1]
                rates_det_good2 = rates_det[start_index2:end_index2+1]
                rates_det_good3 = rates_det[start_index3:end_index3+1]
                rates_det_good4 = rates_det[start_index4:end_index4+1]

                null1_sum_ijkappa = sum(rates_null_good1)
                alter1_sum_ijkappa = sum(rates_det_good1 + rates_null_good1)

                null2_sum_ijkappa = sum(rates_null_good2)
                alter2_sum_ijkappa = sum(rates_det_good2 + rates_null_good2)

                null3_sum_ijkappa = sum(rates_null_good3)
                alter3_sum_ijkappa = sum(rates_det_good3 + rates_null_good3)

                null4_sum_ijkappa = sum(rates_null_good4)
                alter4_sum_ijkappa = sum(rates_det_good4 + rates_null_good4)

                print('\nEr range keep all dsnb: ', len(rates_null_good1), 'bins from ', 
                      Er_bincenters[start_index1], ' to ', Er_bincenters[end_index1], 
                      '\nnull_sum_ijkappa = ', null1_sum_ijkappa, 
                      '\nalter_sum_ijkappa = ', alter1_sum_ijkappa,

                     '\n\nEr range remove all bgs except atm and dsnb exists: ', len(rates_null_good2), 'bins from ', 
                      Er_bincenters[start_index2], ' to ', Er_bincenters[end_index2], 
                      '\nnull_sum_ijkappa = ', null2_sum_ijkappa, 
                      '\nalter_sum_ijkappa = ', alter2_sum_ijkappa, 

                      '\n\nEr range keep dsnb greater than atm: ', len(rates_null_good3), 'bins from ', 
                      Er_bincenters[start_index3], ' to ', Er_bincenters[end_index3], 
                      '\nnull_sum_ijkappa = ', null3_sum_ijkappa, 
                      '\nalter_sum_ijkappa = ', alter3_sum_ijkappa, 

                      '\n\nEr range keep dsnb greater than else bgs and greater than fraction of atm: ', 
                      len(rates_null_good3), 'bins from ', 
                      Er_bincenters[start_index4], ' to ', Er_bincenters[end_index4], 
                      '\nnull_sum_ijkappa = ', null4_sum_ijkappa, 
                      '\nalter_sum_ijkappa = ', alter4_sum_ijkappa, 

                      '\n')
               
                for alpha_power in alphas_powers:
                    dict_key = str(alpha_power)
                    alpha, power = alpha_power
                    Z_alpha = round(stats.norm.ppf(alpha), 3)
                    Phi_minus1 = round(stats.norm.ppf(power), 3)


                    #keep all dsnb
                    DT_method2_good1,_,_,_,_ = get_nume_DT_alphabeta_G_method2(exposures, 
                                        null1_sum_ijkappa.value, alter1_sum_ijkappa.value, 
                                        alpha, power, simnum = 500000, 
                                         plot= False, print_check = False)
                    result_pd[detector+'_'+metallicity+'_'+(''.join(eff_corr))+'_allDSNBMethod2'][str(alpha_power)] = DT_method2_good1
                    print('keep all dsnb method2 DT = ', DT_method2_good1, '\n')

                    #remove all bgs except atm and dsnb exists
                    DT_method2_good2,_,_,_,_ = get_nume_DT_alphabeta_G_method2(exposures, 
                                        null2_sum_ijkappa.value, alter2_sum_ijkappa.value, 
                                        alpha, power, simnum = 500000, 
                                         plot= False, print_check = False)
                    result_pd[detector+'_'+metallicity+'_'+(''.join(eff_corr))+'_noelsebgMethod2'][str(alpha_power)] = DT_method2_good2
                    print('remove all bgs except atm and dsnb exists method2 DT = ', DT_method2_good2, '\n')

                    #keep dsnb greater than atm 
                    DT_method2_good3,_,_,_,_ = get_nume_DT_alphabeta_G_method2(exposures, 
                                        null3_sum_ijkappa.value, alter3_sum_ijkappa.value, 
                                        alpha, power, simnum = 500000, 
                                         plot= False, print_check = False)
                    result_pd[detector+'_'+metallicity+'_'+(''.join(eff_corr))+'_lessatmbgMethod2'][str(alpha_power)] = DT_method2_good3

                    print('keep dsnb greater than atm  method2 DT = ', DT_method2_good3, '\n')

                    #keep dsnb greater than else bgs and greater than fraction of atm
                    DT_method2_good4,_,_,_,_ = get_nume_DT_alphabeta_G_method2(exposures, 
                                        null4_sum_ijkappa.value, alter4_sum_ijkappa.value, 
                                        alpha, power, simnum = 500000, 
                                         plot= False, print_check = False)
                    result_pd[detector+'_'+metallicity+'_'+(''.join(eff_corr))+'_lessatmlesselseMethod2'][str(alpha_power)] = DT_method2_good4

                    if end_index1-start_index1>=30:
                        DT_method1_good1 = get_analytic_calDcalT_shape(pd.DataFrame(rates_null_good1), 
                                                               pd.DataFrame(rates_det_good1), 
                                                               Phi_minus1, Z_alpha)
                        print('keep all dsnb method1 DT = ', DT_method1_good1, '\n')
                        result_pd[detector+'_'+metallicity+'_'+(''.join(eff_corr))+'_allDSNBMethod1'][str(alpha_power)] = DT_method1_good1
                    if end_index2-start_index2>=30:
                        DT_method1_good2 = get_analytic_calDcalT_shape(pd.DataFrame(rates_null_good2), 
                                                           pd.DataFrame(rates_det_good2), 
                                                           Phi_minus1, Z_alpha)
                        print('remove all bgs except atm and dsnb exists method1 DT = ', DT_method1_good2, '\n')
                        result_pd[detector+'_'+metallicity+'_'+(''.join(eff_corr))+'_noelsebgMethod1'][str(alpha_power)] = DT_method1_good2

                    if end_index3-start_index3>=30:
                        DT_method1_good3 = get_analytic_calDcalT_shape(pd.DataFrame(rates_null_good3), 
                                                           pd.DataFrame(rates_det_good3), 
                                                           Phi_minus1, Z_alpha)
                        print('keep dsnb greater than atm method1 DT = ', DT_method1_good3, '\n')
                        result_pd[detector+'_'+metallicity+'_'+(''.join(eff_corr))+'_lessatmbgMethod1'][str(alpha_power)] = DT_method1_good3

                    if end_index4-start_index4>=30:
                        DT_method1_good4 = get_analytic_calDcalT_shape(pd.DataFrame(rates_null_good4), 
                                                           pd.DataFrame(rates_det_good4), 
                                                           Phi_minus1, Z_alpha)
                        print('keep dsnb greater than else bgs and greater than fraction of atm method1 DT = ', DT_method1_good4, '\n')
                        result_pd[detector+'_'+metallicity+'_'+(''.join(eff_corr))+'_lessatmlesselseMethod1'][str(alpha_power)] = DT_method1_good4
# Out:
# ('', '')
# CJPL
#
# Er range keep all dsnb:  39 bins from  1.0810353001850492  to  325.5932599484624
# null_sum_ijkappa =  128.67252342473665 1 / (t yr)
# alter_sum_ijkappa =  128.6810712086379 1 / (t yr)
#
# Er range remove all bgs except atm and dsnb exists:  19 bins from  21.801689735515524  to  325.5932599484624
# null_sum_ijkappa =  0.01341185568717819 1 / (t yr)
# alter_sum_ijkappa =  0.01457348836560448 1 / (t yr)
#
# Er range keep dsnb greater than atm:  17 bins from  1.0810353001850492  to  11.955289551386555
# null_sum_ijkappa =  128.6558509857961 1 / (t yr)
# alter_sum_ijkappa =  128.662400479345 1 / (t yr)
#
# Er range keep dsnb greater than else bgs and greater than fraction of atm:  17 bins from  18.761071598035507  to  29.441177981824193
# null_sum_ijkappa =  0.00199544408227892 1 / (t yr)
# alter_sum_ijkappa =  0.0028261832664781914 1 / (t yr)
#
# keep all dsnb method2 DT =  1000000.0
#
# remove all bgs except atm and dsnb exists method2 DT =  199315.8240990843
#
# ...

# %%
result_pd
# Out:
#               CJPL_high__allDSNBMethod1 CJPL_high__allDSNBMethod2  \
# (0.001, 0.9)             42211001.95891                 1000000.0
# (0.01, 0.9)             28747491.152525                 1000000.0
# (0.1, 0.9)               14517990.69051                 1000000.0
# (0.001, 0.95)           49511565.926604                 1000000.0
# (0.01, 0.95)            34823155.637959                 1000000.0
# (0.1, 0.95)             18919839.653065                 1000000.0
# (0.001, 0.8)            34142114.578138                 1000000.0
# (0.01, 0.8)             22163330.416917                 1000000.0
# (0.1, 0.8)                9962697.25536                 1000000.0
#
#               CJPL_high__noelsebgMethod1 CJPL_high__noelsebgMethod2  \
# (0.001, 0.9)                         NaN              199315.824099
# (0.01, 0.9)                          NaN              136889.997879
# (0.1, 0.9)                           NaN               69763.250297
# ...

# %%
result_pd
# Out:
#               CJPL_high__allDSNBMethod1 CJPL_high__allDSNBMethod2  \
# (0.001, 0.9)             42211001.95891                 1000000.0
# (0.01, 0.9)             28747491.152525                 1000000.0
# (0.1, 0.9)               14517990.69051                 1000000.0
# (0.001, 0.95)           49511565.926604                 1000000.0
# (0.01, 0.95)            34823155.637959                 1000000.0
# (0.1, 0.95)             18919839.653065                 1000000.0
# (0.001, 0.8)            34142114.578138                 1000000.0
# (0.01, 0.8)             22163330.416917                 1000000.0
# (0.1, 0.8)                9962697.25536                 1000000.0
#
#               CJPL_high__noelsebgMethod1 CJPL_high__noelsebgMethod2  \
# (0.001, 0.9)                         NaN              199315.824099
# (0.01, 0.9)                          NaN              136889.997879
# (0.1, 0.9)                           NaN               69763.250297
# ...

# %%
result_pd.to_csv('dsnb_Ar_DT_optimized_numeNa_Erbinning.csv')

# %% [markdown]
# # find binning range

# %%
Er_range_pd = pd.DataFrame(index = [detector+'_'+metallicity+'_'+(''.join(eff_corr)) 
                                  for detector in detectors 
                                  for  metallicity in metallicities
                                  for eff_corr in effs_corrs ],
                         columns=['Er_range '+method  
                    for method in ['allDSNBMethod2', 'noelsebgMethod2', 'lessatmbgMethod2', 'lessatmlesselseMethod2']])

Er_range_pd
# Out:
#                                    Er_range allDSNBMethod2  \
# CJPL_high_                                             NaN
# CJPL_high_NR_Argon_tot_smear0.1                        NaN
# CJPL_low_                                              NaN
# CJPL_low_NR_Argon_tot_smear0.1                         NaN
# Kamioka_high_                                          NaN
# Kamioka_high_NR_Argon_tot_smear0.1                     NaN
# Kamioka_low_                                           NaN
# Kamioka_low_NR_Argon_tot_smear0.1                      NaN
# LNGS_high_                                             NaN
# LNGS_high_NR_Argon_tot_smear0.1                        NaN
# LNGS_low_                                              NaN
# LNGS_low_NR_Argon_tot_smear0.1                         NaN
# SURF_high_                                             NaN
# SURF_high_NR_Argon_tot_smear0.1                        NaN
# SURF_low_                                              NaN
# ...

# %%
Er_bins = list(binned_1d_pd['Argon_Er_bin [keV]'])
for eff_corr in effs_corrs:
    eff, corr = eff_corr 
    print(eff_corr)
    for detector in detectors:
        print(detector)
        for metallicity in metallicities:
            pcles_det = ['dsnb']
            select_col_det  = [col for col in binned_1d_pd.columns 
                               if '_'+eff+'_' in col and corr in col and 
                               metallicity in col and any(pcle in col for pcle in pcles_det)]

            pcles_null_NR_woatm =['hep', '8B']
            pcles_null_NR = ['hep', '8B','atmNu_'+detector+'_avg']
            pcles_null_atm_NR = ['atmNu_'+detector+'_avg']
            select_col_null_woatm  = [col for col in binned_1d_pd.columns 
                                      if '_'+eff+'_' in col and corr in col and 
                                      metallicity in col and any(pcle in col for pcle in pcles_null_NR_woatm)]
            select_col_null_atm  = [col for col in binned_1d_pd.columns 
                                    if '_'+eff+'_' in col and corr in col and 
                                    metallicity in col and any(pcle in col for pcle in pcles_null_atm_NR)]

            select_col_null  = [col for col in binned_1d_pd.columns 
                                if '_'+eff+'_' in col and corr in col and 
                                metallicity in col and any(pcle in col for pcle in pcles_null_NR)]

            if len(
                select_col_det) !=len(pcles_det) or len(
                select_col_null) !=len(pcles_null_NR) or len(
                select_col_null_woatm) !=len(pcles_null_NR_woatm) or len(
                select_col_null_atm) !=len(pcles_null_atm_NR):
                print('wrong selection',
                     select_col_det, pcles_det,'\n',
                     select_col_null, pcles_null_NR, '\n',
                     select_col_null_woatm, pcles_null_NR_woatm, '\n',
                     select_col_null_atm, pcles_null_atm_NR)
                break
            else:

                rates_det = list(np.sum(binned_1d_pd[select_col_det], axis = 1))/u.tonne/u.yr
                rates_null = list(np.sum(binned_1d_pd[select_col_null], axis = 1))/u.tonne/u.yr
                rates_null_woatm = list(np.sum(binned_1d_pd[select_col_null_woatm], axis = 1))/u.tonne/u.yr
                rates_null_atm = list(np.sum(binned_1d_pd[select_col_null_atm], axis = 1))/u.tonne/u.yr


                #keep all dsnb
                good1 = rates_det>0

                #remove all bgs except atm and dsnb exists
                good2 = np.multiply(rates_det>0, rates_null_woatm==0)

                #keep dsnb greater than atm
                good3 = rates_null_atm<rates_det 

                #keep dsnb greater than else bgs and greater than fraction of atm
                good4 = np.multiply(rates_null_atm<4*rates_det, rates_null_woatm<rates_det)


                start_index1, end_index1 = min(np.where(good1)[0]), max(np.where(good1)[0])
                start_index2, end_index2 = min(np.where(good2)[0]), max(np.where(good2)[0])
                start_index3, end_index3 = min(np.where(good3)[0]), max(np.where(good3)[0])
                start_index4, end_index4 = min(np.where(good4)[0]), max(np.where(good4)[0])

                rates_null_good1 = rates_null[start_index1:end_index1+1]
                rates_null_good2 = rates_null[start_index2:end_index2+1]
                rates_null_good3 = rates_null[start_index3:end_index3+1]
                rates_null_good4 = rates_null[start_index4:end_index4+1]

                Er_range_method1 =str(round(float(Er_bins[start_index1].split('_')[0]), 
                                       3))+'-'+ str(round(float(Er_bins[end_index1].split('_')[1]), 3))
                Er_range_method2 =str(round(float(Er_bins[start_index2].split('_')[0]), 
                                       3))+'-'+ str(round(float(Er_bins[end_index2].split('_')[1]), 3))
                Er_range_method3 =str(round(float(Er_bins[start_index3].split('_')[0]), 
                                       3))+'-'+ str(round(float(Er_bins[end_index3].split('_')[1]), 3))
                Er_range_method4 =str(round(float(Er_bins[start_index4].split('_')[0]), 
                                       3))+'-'+ str(round(float(Er_bins[end_index4].split('_')[1]), 3))
                
                Er_range_pd['Er_range allDSNBMethod2'][detector+'_'+metallicity+'_'+(''.join(eff_corr))] = Er_range_method1
                Er_range_pd['Er_range noelsebgMethod2'][detector+'_'+metallicity+'_'+(''.join(eff_corr))] = Er_range_method2
                Er_range_pd['Er_range lessatmbgMethod2'][detector+'_'+metallicity+'_'+(''.join(eff_corr))] = Er_range_method3
                Er_range_pd['Er_range lessatmlesselseMethod2'][detector+'_'+metallicity+'_'+(''.join(eff_corr))] = Er_range_method4
                
                
                print('\nEr range keep all dsnb: ', len(rates_null_good1), 'bins from ', 
                      Er_bins[start_index1].split('_')[0], ' to ', Er_bins[end_index1].split('_')[1], 

                     '\n\nEr range remove all bgs except atm and dsnb exists: ', len(rates_null_good2), 'bins from ', 
                      Er_bins[start_index2].split('_')[0], ' to ', Er_bins[end_index2].split('_')[1], 
                      
                      '\n\nEr range keep dsnb greater than atm: ', len(rates_null_good3), 'bins from ', 
                      Er_bins[start_index3].split('_')[0], ' to ', Er_bins[end_index3].split('_')[1], 

                      '\n\nEr range keep dsnb greater than else bgs and greater than fraction of atm: ', 
                      len(rates_null_good4), 'bins from ', 
                      Er_bins[start_index4].split('_')[0], ' to ', Er_bins[end_index4].split('_')[1], 

                      '\n')
# Out:
# ('', '')
# CJPL
#
# Er range keep all dsnb:  39 bins from  1.0  to  350.0
#
# Er range remove all bgs except atm and dsnb exists:  19 bins from  20.16741704159296  to  350.0
#
# Er range keep dsnb greater than atm:  17 bins from  1.0  to  12.851467943923742
#
# Er range keep dsnb greater than else bgs and greater than fraction of atm:  4 bins from  17.354726154478058  to  31.648113033020206
#
#
# Er range keep all dsnb:  39 bins from  1.0  to  350.0
#
# Er range remove all bgs except atm and dsnb exists:  19 bins from  20.16741704159296  to  350.0
#
# Er range keep dsnb greater than atm:  17 bins from  1.0  to  12.851467943923742
#
# Er range keep dsnb greater than else bgs and greater than fraction of atm:  4 bins from  17.354726154478058  to  31.648113033020206
#
# Kamioka
#
# Er range keep all dsnb:  39 bins from  1.0  to  350.0
#
# Er range remove all bgs except atm and dsnb exists:  19 bins from  20.16741704159296  to  350.0
#
# ...

# %%
Er_range_pd
# Out:
#                                    Er_range allDSNBMethod2  \
# CJPL_high_                                       1.0-350.0
# CJPL_high_NR_Argon_tot_smear0.1                6.064-350.0
# CJPL_low_                                        1.0-350.0
# CJPL_low_NR_Argon_tot_smear0.1                 6.064-350.0
# Kamioka_high_                                    1.0-350.0
# Kamioka_high_NR_Argon_tot_smear0.1             6.064-350.0
# Kamioka_low_                                     1.0-350.0
# Kamioka_low_NR_Argon_tot_smear0.1              6.064-350.0
# LNGS_high_                                       1.0-350.0
# LNGS_high_NR_Argon_tot_smear0.1                6.064-350.0
# LNGS_low_                                        1.0-350.0
# LNGS_low_NR_Argon_tot_smear0.1                 6.064-350.0
# SURF_high_                                       1.0-350.0
# SURF_high_NR_Argon_tot_smear0.1                6.064-350.0
# SURF_low_                                        1.0-350.0
# ...

# %%
Er_range_pd.to_csv('dsnb_Ar_Erbinning_range.csv')
